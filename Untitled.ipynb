# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer_df=pd.read_csv("files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv")
display(customer_df.head(10))
print(customer_df.shape)
print(customer_df.info)
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
# 5  OC83172      Oregon              8256.297800      Yes     Basic  Bachelor
# 6  XZ87318      Oregon              5380.898636      Yes     Basic   College
# 7  CF85061     Arizona              7216.100311       No   Premium    Master
# 8  DY87989      Oregon             24127.504020      Yes     Basic  Bachelor
# 9  BQ94931      Oregon              7388.178085       No  Extended   College
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# ...

# %%
# converting column names to snake type

customer_df.columns = [x.lower() for x in customer_df.columns]
customer_df.columns = customer_df.columns.str.replace(' ','_')

display(customer_df.head(10))
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
# 5  OC83172      Oregon              8256.297800      Yes     Basic  Bachelor
# 6  XZ87318      Oregon              5380.898636      Yes     Basic   College
# 7  CF85061     Arizona              7216.100311       No   Premium    Master
# 8  DY87989      Oregon             24127.504020      Yes     Basic  Bachelor
# 9  BQ94931      Oregon              7388.178085       No  Extended   College
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# ...

# %%
# turning effective to date into datetime type

customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])

# %%
# checking for nulls

customer_df.isnull().sum() # - no nulls
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numericals = customer_df.select_dtypes(include=numerics)

categoricals = customer_df.select_dtypes(include=object)

display(numericals.head())
display(categoricals.head())
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
def cont_disc(numericals):
    
    cont = pd.DataFrame()
    disc = pd.DataFrame()
    notdisc = cont.columns
    
    for col in numericals.columns:
        if numericals[col].dtypes == float:
            cont = pd.concat([cont,numericals[col]], axis=1)
     
    disc = numericals.drop(notdisc, axis=1)     
    
    return (cont,disc)

# %%
cont_disc(numericals)

display(cont.head())
display(disc.head())
# Out:
#    customer_lifetime_value  total_claim_amount
# 0              2763.519279          384.811147
# 1              6979.535903         1131.464935
# 2             12887.431650          566.472247
# 3              7645.861827          529.881344
# 4              2813.692575          138.130879
#    income  monthly_premium_auto  months_since_last_claim  \
# 0   56274                    69                       32
# 1       0                    94                       13
# 2   48767                   108                       18
# 3       0                   106                       18
# 4   43836                    73                       12
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# ...

# %%
def uvalue_check(categoricals):
    
    uniques = {col: categoricals[col].unique() for col in categoricals.columns}
    
    return  (uniques)

# %%
uvalue_check(categoricals)

# There are no nan values and nothing apparent that needs correct
# Out:
# {'customer': array(['BU79786', 'QZ44356', 'AI49188', ..., 'TD14365', 'UP19263',
#         'Y167826'], dtype=object),
#  'state': array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon'],
#        dtype=object),
#  'response': array(['No', 'Yes'], dtype=object),
#  'coverage': array(['Basic', 'Extended', 'Premium'], dtype=object),
#  'education': array(['Bachelor', 'College', 'Master', 'High School or Below', 'Doctor'],
#        dtype=object),
#  'employmentstatus': array(['Employed', 'Unemployed', 'Medical Leave', 'Disabled', 'Retired'],
#        dtype=object),
#  'gender': array(['F', 'M'], dtype=object),
#  'location_code': array(['Suburban', 'Rural', 'Urban'], dtype=object),
#  'marital_status': array(['Married', 'Single', 'Divorced'], dtype=object),
#  'policy_type': array(['Corporate Auto', 'Personal Auto', 'Special Auto'], dtype=object),
#  'policy': array(['Corporate L3', 'Personal L3', 'Corporate L2', 'Personal L1',
# ...
